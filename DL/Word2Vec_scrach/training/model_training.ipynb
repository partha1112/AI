# %%
import nltk
nltk.download("brown")

from nltk.corpus import brown

sentences = brown.sents()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.

# %%
type(sentences)
# Out:
# nltk.corpus.reader.util.ConcatenatedCorpusView

# %%
print(sentences[0])
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', "Atlanta's", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']

# %%
from gensim.models import Word2Vec

model = Word2Vec(
    vector_size=100,  # Embedding dimension
    window=5,         # Context window size
    min_count=1,      # Include all words
    workers=4,        # Parallel processing
    sg=1,             # 1 = Skip-Gram, 0 = CBOW
    epochs=50         # Number of training passes
)

# %%
model.build_vocab(sentences)

# %%
print("Vocabulary Size:", len(model.wv.index_to_key))
print("Vocabulary:", model.wv.index_to_key)
# Out:
# Vocabulary Size: 56057
# Vocabulary: ['the', ',', '.', 'of', 'and', 'to', 'a', 'in', 'that', 'is', 'was', 'for', '``', "''", 'The', 'with', 'it', 'as', 'he', 'his', 'on', 'be', ';', 'I', 'by', 'had', 'at', '?', 'not', 'are', 'from', 'or', 'this', 'have', 'an', 'which', '--', 'were', 'but', 'He', 'her', 'one', 'they', 'you', 'all', 'would', 'him', 'their', 'been', ')', '(', 'has', 'will', 'who', 'more', 'out', 'It', 'we', 'she', 'said', 'there', 'up', 'In', ':', 'than', 'them', 'into', 'no', 'its', 'about', 'so', 'when', 'can', 'only', 'other', '!', 'could', 'time', 'if', 'what', 'some', 'But', 'A', 'two', 'any', 'may', 'do', 'first', 'like', 'these', 'over', 'such', 'This', 'me', 'my', 'man', 'our', 'made', 'new', 'most', 'now', 'then', 'must', 'also', 'Af', 'did', 'even', 'back', 'before', 'years', 'through', 'And', 'many', 'She', 'much', 'way', 'down', 'your', 'should', 'There', 'where', 'They', 'Mr.', 'after', 'people', 'because', 'too', 'little', 'those', 'own', 'very', 'make', 'good', 'each', 'well', 'work', 'just', 'men', 'If', 'still', 'see', 'get', 'between', 'long', 'being', 'world', 'same', 'know', 'We', 'life', 'us', 'might', 'never', 'year', 'For', 'under', 'both', 'last', 'off', 'how', 'day', 'came', 'against', 'used', 'great', 'here', 'go', 'himself', 'right', 'come', 'When', 'few', 'take', 'New', 'another', 'American', 'old', 'use', 'while', 'around', 'three', 'As', 'state', 'without', 'found', 'again', 'Mrs.', 'His', 'place', '1', 'home', 'You', 'small', 'thought', 'went', 'say', 'upon', 'What', 'left', 'got', 'number', 'part', 'course', 'United', 'high', 'since', 'away', 'during', 'always', 'fact', '2', 'States', 'does', 'until', 'every', 'water', 'think', 'To', 'enough', 'less', 'took', 'put', 'head', 'something', 'One', 'hand', 'school', 'once', 'told', 'At', 'far', 'set', 'almost', 'better', 'public', 'house', 'end', 'night', 'called', 'knew', 'find', "didn't", 'system', 'going', 'eyes', "don't", 'however', 'asked', 'group', 'toward', 'give', 'days', 'though', 'point', 'program', 'possible', 'given', 'side', 'per', 'face', 'present', 'looked', 'room', 'important', 'look', 'business', 'order', 'next', 'things', 'John', 'young', 'become', 'No', 'nothing', 'That', 'felt', 'later', 'social', 'Then', 'case', 'rather', 'large', 'need', 'form', 'saw', 'often', 'On', 'These', 'least', 'along', 'children', 'second', 'best', 'several', 'early', 'seemed', 'ever', 'Of', 'thing', 'want', 'power', 'four', 'mind', 'interest', 'within', 'light', 'turned', 'area', "'", 'big', 'done', 'among', 'door', 'began', 'country', 'members', 'problem', 'sense', 'family', 'general', 'development', 'kind', 'different', 'whole', 'matter', 'open', 'war', 'itself', 'help', 'certain', 'York', 'God', 'human', 'others', 'let', 'name', 'means', 'example', '3', 'action', 'hands', 'gave', 'feet', 'yet', 'line', 'taken', 'With', 'past', 'law', 'seen', 'above', 'All', 'across', 'either', 'local', 'experience', 'government', 'show', 'quite', 'car', 'themselves', 'body', 'words', 'Now', "I'm", 'history', 'really', 'anything', 'times', 'death', 'half', 'period', 'State', 'word', 'together', 'held', 'money', 'city', 'having', 'information', 'cannot', 'whether', 'already', 'President', 'week', 'white', 'shall', 'political', 'brought', 'seems', 'making', 'real', 'whose', 'question', 'keep', 'moment', 'ago', 'today', 'After', 'known', 'service', 'tell', 'became', 'behind', 'free', 'field', 'result', 'why', 'five', 'problems', 'heard', 'available', 'sure', 'reason', 'study', 'position', 'change', 'job', 'probably', 'boy', 'areas', 'individual', 'special', 'Miss', 'So', 'close', 'seem', 'wife', 'major', 'turn', 'wanted', 'full', 'am', 'church', 'cost', 'necessary', 'policy', 'voice', 'economic', 'clear', 'company', 'air', 'woman', 'front', 'true', 'able', 'feel', 'age', 'future', 'love', 'perhaps', 'community', 'office', 'provide', 'effect', 'level', 'national', 'stood', 'girl', 'How', 'Some', 'child', 'total', 'rate', 'control', 'morning', 'common', 'short', '4', 'Washington', 'r ...

# %%
model.train(
    sentences,
    total_examples=model.corpus_count,
    epochs=model.epochs
)
# Out:
# (42707025, 58059600)

# %%
vector = model.wv["word"]
print(vector)
# Out:
# [ 0.10646795  0.19017611  0.14958087 -0.343802   -0.7671166  -0.5324249
#   0.11019932 -0.26051122 -0.3879634  -0.07046966 -0.40762234 -0.44889078
#   0.41118732  0.22657587 -0.4978813  -0.01539944  0.11272598 -0.06699114
#   0.7567934  -1.1232499  -0.05384891  0.06170905  0.2629142   0.54143053
#  -0.21494739  0.33439735  0.07259964 -0.5830864   0.1866086   0.10555714
#   0.33845562  0.63547903  0.6566747  -0.4547306  -0.0994275  -0.29066724
#   0.42819983  0.4392657  -0.2972438  -0.06478336  0.14752752 -0.5631385
#   1.1879163  -0.06205274 -0.29518554 -0.33627507 -0.86499834 -0.48953143
#   0.28159595  0.39386404  0.08701197  0.5306383   0.02260516 -0.5124426
#  -0.06585006 -0.09370514 -0.14930037 -0.34848195 -0.45110282  0.00160747
#  -0.25396472 -0.00629418  0.486271    0.46971658 -0.6179525   0.6198437
#   0.3630771   0.20437098 -0.48479936  0.7574076   0.27390227  0.27859682
#   0.39498892 -0.05895041  0.5954643  -0.24979128  0.00501226  0.2743099
#  -0.10326166 -0.16852556 -0.44878966 -0.04023513 -0.87787396  0.24470821
#  -0.4650942   0.04509673  0.22670247  0.7054426   0.78918743  0.03165935
#   1.2957451   0.34235638  0.0437989  -0.5869413  -0.0030146   0.42636055
#   0.8354104  -0.14152686 -0.22978997  0.13344851]

# %%
print(model.wv.most_similar("learning"))
# Out:
# [('Childhood', 0.5820976495742798), ('maladjustments', 0.5670691132545471), ('highwayman', 0.5528889298439026), ('financially', 0.5516047477722168), ('cohere', 0.5361970663070679), ("Gorham's", 0.5357658267021179), ('heedless', 0.5313533544540405), ('Mennen', 0.5304839015007019), ('self-discipline', 0.5271536111831665), ('breaker', 0.5257879495620728)]

# %%
model.save("word2vec_model.model")
